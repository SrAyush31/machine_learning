# %% [markdown]
# <a href="https://colab.research.google.com/github/SrAyush31/machine_learning/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**SVM on top of the Cancer Dataset**

# %%
# !mkdir -p /root/.kaggle

# %%
# !mv kaggle.json /root/.kaggle/

# %%
import kaggle

# %%
# !kaggle datasets download -d uciml/breast-cancer-wisconsin-data
# Out:
# ...
#   0% 0.00/48.6k [00:00<?, ?B/s]
# 100% 48.6k/48.6k [00:00<00:00, 14.9MB/s]

# %%
# !unzip -q /content/breast-cancer-wisconsin-data.zip

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('data.csv')

# %%
dataset.describe()
# Out:
#                  id  radius_mean  ...  fractal_dimension_worst  Unnamed: 32
# count  5.690000e+02   569.000000  ...               569.000000          0.0
# mean   3.037183e+07    14.127292  ...                 0.083946          NaN
# std    1.250206e+08     3.524049  ...                 0.018061          NaN
# min    8.670000e+03     6.981000  ...                 0.055040          NaN
# 25%    8.692180e+05    11.700000  ...                 0.071460          NaN
# 50%    9.060240e+05    13.370000  ...                 0.080040          NaN
# 75%    8.813129e+06    15.780000  ...                 0.092080          NaN
# max    9.113205e+08    28.110000  ...                 0.207500          NaN
#
# [8 rows x 32 columns]

# %%
dataset.tail()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 564  926424         M  ...                  0.07115          NaN
# 565  926682         M  ...                  0.06637          NaN
# 566  926954         M  ...                  0.07820          NaN
# 567  927241         M  ...                  0.12400          NaN
# 568   92751         B  ...                  0.07039          NaN
#
# [5 rows x 33 columns]

# %%
dataset.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
dataset['diagnosis'] = dataset['diagnosis'].map({'M':0,'B':1})
# Malignant = 0, Benign = 1
dataset.head()
# Out:
#          id  diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302          0  ...                  0.11890          NaN
# 1    842517          0  ...                  0.08902          NaN
# 2  84300903          0  ...                  0.08758          NaN
# 3  84348301          0  ...                  0.17300          NaN
# 4  84358402          0  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
dataset.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
dataset.corr()
# Out:
#                                id  ...  Unnamed: 32
# id                       1.000000  ...          NaN
# radius_mean              0.074626  ...          NaN
# texture_mean             0.099770  ...          NaN
# perimeter_mean           0.073159  ...          NaN
# area_mean                0.096893  ...          NaN
# smoothness_mean         -0.012968  ...          NaN
# compactness_mean         0.000096  ...          NaN
# concavity_mean           0.050080  ...          NaN
# concave points_mean      0.044158  ...          NaN
# symmetry_mean           -0.022114  ...          NaN
# fractal_dimension_mean  -0.052511  ...          NaN
# radius_se                0.143048  ...          NaN
# texture_se              -0.007526  ...          NaN
# perimeter_se             0.137331  ...          NaN
# area_se                  0.177742  ...          NaN
# smoothness_se            0.096781  ...          NaN
# compactness_se           0.033961  ...          NaN
# ...

# %%
dataset.shape
# Out:
# (569, 33)

# %%
X = dataset.iloc[:, 2:32]
y = dataset.iloc[:,1]

# %%
X.shape, y.shape
# Out:
# ((569, 30), (569,))

# %% [markdown]
# # Splitting Dataset into Training & Test dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.3, random_state = 109)

# %% [markdown]
# #**Building the SVM model**

# %%
from sklearn import svm

#create a svm classifier
clf = svm.SVC (kernel = 'linear')

#Train the model using training sets
clf.fit(X_train,y_train)

#predict the respnse of test dataset
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cf = confusion_matrix(y_test,y_pred)
print("Confusion_Matrix:",cf)
# Out:
# Confusion_Matrix: [[ 61   2]
#  [  4 104]]

# %%
cf
# Out:
# array([[ 61,   2],
#        [  4, 104]])

# %%
from sklearn import metrics
cm=metrics.ConfusionMatrixDisplay(confusion_matrix=metrics.confusion_matrix(y_pred,y_test,labels=clf.classes_),
display_labels=clf.classes_)
cm.plot(cmap="magma")

# %%
acc = accuracy_score(y_test,y_pred)
print('Accuracy of the SVM model is:',acc*100,'%')
# Out:
# Accuracy of the SVM model is: 96.49122807017544 %
